# %% [markdown]
# <a href="https://colab.research.google.com/github/nataliamelo-dev/analise-dados-brasil/blob/main/primeiro_codigo_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Meu Primeiro Código em Python
nome= "Natalia"
area = "Ciencia de dados"
semestre = 2

print ("Ola, meu nome é Natalia")
print ("Estou estudando na area ciência de dados")
print ("Estou no semestre 2")
# Out:
# Ola, meu nome é Natalia
# Estou estudando na area ciência de dados
# Estou no semestre 2

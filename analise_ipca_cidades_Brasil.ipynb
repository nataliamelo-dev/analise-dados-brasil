# %% [markdown]
# <a href="https://colab.research.google.com/github/nataliamelo-dev/analise-dados-brasil/blob/main/analise_ipca_cidades_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

cidades = ["Aracaju", "BH", "Belem", "Brasil", "Brasilia", "Campo Grande", "Curitiba", "Fortaleza", "Goiania", "Vitoria", "Porto Alegre", "Recife", "Rio", "Salvador", "SP"]

ipca = [0.08, 0.25, 0.44, 0.26, 0.29, 0.46, 0.22, 0.13, -0.11, 0.42, 0.18, 0.05, 0.18, 0.05, 0.38]

plt.barh(cidades, ipca, color="steelblue")
plt.title("IPCA por Cidade - Setembro 2023")
plt.xlabel("Variacao %")
plt.show()
